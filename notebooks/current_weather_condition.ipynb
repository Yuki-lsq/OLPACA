# %%
# !pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40711 sha256=79aaa8bfbfde04ad533aa35b5a3edb90856719510dc710e8963b962e1c46221f
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %%
import requests
from datetime import datetime, timedelta
import googlemaps
import pandas as pd

# %%
def get_current_weather_data(api_key, address):
    # Initialize the Google Maps Geocoding client
    gmaps = googlemaps.Client(key=api_key)

    # Geocode the address
    geocode_result = gmaps.geocode(address)

    print(type(geocode_result))

    # Check if there's a valid result
    if not geocode_result:
        print('Location not found.')
        return None, None

    # Extract latitude and longitude
    latitude = geocode_result[0]['geometry']['location']['lat']
    longitude = geocode_result[0]['geometry']['location']['lng']

    print(type(latitude))


    # Real-time weather data
    real_time_url = "https://weatherapi-com.p.rapidapi.com/current.json"
    # real_time_querystring = {"q": f"{latitude},{longitude}"}
    real_time_querystring = {"q": f"{address}"}
    real_time_headers = {
        "X-RapidAPI-Key": "85c12fb348mshdd5be0724719438p1137ddjsnff47f3d0d12a",
        "X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"
    }

    # Make the real-time weather API request
    real_time_response = requests.get(real_time_url, headers=real_time_headers, params=real_time_querystring)
    real_time_data = real_time_response.json()

    # Forecasted weather data
    forecast_url = "https://weatherapi-com.p.rapidapi.com/forecast.json"
    # forecast_querystring = {"q": f"{latitude},{longitude}", "days": "3"}
    forecast_querystring = {"q": f"{address}", "days": "3"}
    forecast_headers = {
        "X-RapidAPI-Key": "85c12fb348mshdd5be0724719438p1137ddjsnff47f3d0d12a",
        "X-RapidAPI-Host": "weatherapi-com.p.rapidapi.com"
    }

    # Make the forecasted weather API request
    forecast_response = requests.get(forecast_url, headers=forecast_headers, params=forecast_querystring)
    forecast_data = forecast_response.json()

    return real_time_data, forecast_data

# %%
# Example usage:
api_key = 'AIzaSyAoSVj2Tp6GVdHlmFXHDuEnOI4c3ahqQHU'
address = '1 Austin Crescent East, Yarraville'
real_time_data, forecast_data = get_current_weather_data(api_key, address)
print(real_time_data)
# Out:
# <class 'list'>
# <class 'float'>
# {'location': {'name': 'Yarraville', 'region': 'Victoria', 'country': 'Australia', 'lat': -37.82, 'lon': 144.9, 'tz_id': 'Australia/Melbourne', 'localtime_epoch': 1700910896, 'localtime': '2023-11-25 22:14'}, 'current': {'last_updated_epoch': 1700910000, 'last_updated': '2023-11-25 22:00', 'temp_c': 16.3, 'temp_f': 61.3, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 2.2, 'wind_kph': 3.6, 'wind_degree': 233, 'wind_dir': 'SW', 'pressure_mb': 1009.0, 'pressure_in': 29.79, 'precip_mm': 0.43, 'precip_in': 0.02, 'humidity': 92, 'cloud': 100, 'feelslike_c': 16.3, 'feelslike_f': 61.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 2.5, 'gust_kph': 4.0}}

# %%
api_key = 'AIzaSyAoSVj2Tp6GVdHlmFXHDuEnOI4c3ahqQHU'
address = 'Greensborough'
real_time_data, forecast_data = get_current_weather_data(api_key, address)

print(real_time_data)
print(forecast_data)
# Out:
# <class 'list'>
# {'location': {'name': 'Greensborough', 'region': 'Victoria', 'country': 'Australia', 'lat': -37.69, 'lon': 145.12, 'tz_id': 'Australia/Melbourne', 'localtime_epoch': 1700906427, 'localtime': '2023-11-25 21:00'}, 'current': {'last_updated_epoch': 1700905500, 'last_updated': '2023-11-25 20:45', 'temp_c': 16.9, 'temp_f': 62.4, 'is_day': 0, 'condition': {'text': 'Patchy light rain', 'icon': '//cdn.weatherapi.com/weather/64x64/night/293.png', 'code': 1180}, 'wind_mph': 10.1, 'wind_kph': 16.2, 'wind_degree': 293, 'wind_dir': 'WNW', 'pressure_mb': 1008.0, 'pressure_in': 29.78, 'precip_mm': 1.6, 'precip_in': 0.06, 'humidity': 86, 'cloud': 64, 'feelslike_c': 16.9, 'feelslike_f': 62.4, 'vis_km': 9.0, 'vis_miles': 5.0, 'uv': 4.0, 'gust_mph': 16.6, 'gust_kph': 26.7}}
# ...

# %%
api_key = 'AIzaSyAoSVj2Tp6GVdHlmFXHDuEnOI4c3ahqQHU'
address = 'Stop 1, Parkville, Melbourne'
real_time_data, forecast_data = get_current_weather_data(api_key, address)

print(real_time_data)
# Out:
# <class 'list'>
# {'location': {'name': 'Melbourne', 'region': 'Victoria', 'country': 'Australia', 'lat': -37.82, 'lon': 144.97, 'tz_id': 'Australia/Melbourne', 'localtime_epoch': 1700905470, 'localtime': '2023-11-25 20:44'}, 'current': {'last_updated_epoch': 1700904600, 'last_updated': '2023-11-25 20:30', 'temp_c': 21.0, 'temp_f': 69.8, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 11.9, 'wind_kph': 19.1, 'wind_degree': 340, 'wind_dir': 'NNW', 'pressure_mb': 1008.0, 'pressure_in': 29.77, 'precip_mm': 1.69, 'precip_in': 0.07, 'humidity': 60, 'cloud': 75, 'feelslike_c': 21.0, 'feelslike_f': 69.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 4.0, 'gust_mph': 20.0, 'gust_kph': 32.3}}

# %%
api_key = 'AIzaSyAoSVj2Tp6GVdHlmFXHDuEnOI4c3ahqQHU'
address = '560 Lonsdale Street, Melbourne, Australia'
real_time_data, forecast_data = get_current_weather_data(api_key, address)

print(real_time_data)
# Out:
# <class 'list'>
# {'location': {'name': 'Melbourne', 'region': 'Victoria', 'country': 'Australia', 'lat': -37.82, 'lon': 144.97, 'tz_id': 'Australia/Melbourne', 'localtime_epoch': 1700905685, 'localtime': '2023-11-25 20:48'}, 'current': {'last_updated_epoch': 1700905500, 'last_updated': '2023-11-25 20:45', 'temp_c': 17.2, 'temp_f': 63.0, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 12.5, 'wind_kph': 20.2, 'wind_degree': 288, 'wind_dir': 'WNW', 'pressure_mb': 1008.0, 'pressure_in': 29.78, 'precip_mm': 1.69, 'precip_in': 0.07, 'humidity': 85, 'cloud': 80, 'feelslike_c': 17.2, 'feelslike_f': 63.0, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 4.0, 'gust_mph': 20.0, 'gust_kph': 32.3}}

# %%
def to_okta(val):
    if val == 100:
        return 8
    return min(int(val // 12.5), 7)

# %%
def extract_current_weather_data(real_time_data, forecast_data):
    # Extract sunrise and sunset times as strings
    sunrise = forecast_data['forecast']['forecastday'][0]['astro']['sunrise']
    sunset = forecast_data['forecast']['forecastday'][0]['astro']['sunset']

    sunrise_time = datetime.strptime(sunrise, '%I:%M %p')
    sunset_time = datetime.strptime(sunset, '%I:%M %p')

    # Calculate the duration in hours
    duration = round((sunset_time - sunrise_time).total_seconds() / 3600, 1)

    # Create a dictionary with current weather data
    weather_data = {
        'mintemp_c': [forecast_data['forecast']['forecastday'][0]['day']['mintemp_c']],
        'maxtemp_c': [forecast_data['forecast']['forecastday'][0]['day']['maxtemp_c']],
        'precip_mm': [real_time_data['current']['precip_mm']],
        'sunshine': [duration],
        'gust_kph': [real_time_data['current']['gust_kph']],
        'daily_will_it_rain': [forecast_data['forecast']['forecastday'][0]['day']['daily_will_it_rain']],
        'tom_will_it_rain': [forecast_data['forecast']['forecastday'][1]['day']['daily_will_it_rain']],
        'wind_kph': [real_time_data['current']['wind_kph']],
        'humidity': [real_time_data['current']['humidity']],
        'pressure_mb': [real_time_data['current']['pressure_mb']],
        'cloud': [to_okta(real_time_data['current']['cloud'])],
        'temp_c': [real_time_data['current']['temp_c']]
    }

    # Create a DataFrame from the weather data
    df_current = pd.DataFrame(weather_data)

    return df_current

# %%
extract_current_weather_data(real_time_data, forecast_data)
# Out:
#    mintemp_c  maxtemp_c  precip_mm  sunshine  gust_kph  daily_will_it_rain  \
# 0       16.3       26.2       0.06      14.4      13.4                   1
#
#    tom_will_it_rain  wind_kph  humidity  pressure_mb  cloud  temp_c
# 0                 1      25.9        44       1007.0      6    24.0
