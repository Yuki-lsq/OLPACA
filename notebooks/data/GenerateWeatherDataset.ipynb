# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/AI\ Hack/data/
# Out:
# /content/drive/.shortcut-targets-by-id/1CyICcMXzmLngXU_qcKckXHtD2_qKT_eE/AI Hack/data

# %%
import os
from os.path import join
import numpy as np
import pandas as pd

# %%
weatherTable = pd.read_csv("PastWeatherData.csv")
weatherTable = weatherTable.dropna().drop(weatherTable.columns[0],axis=1).reset_index(drop=True)

# %%
morningData = weatherTable.filter(regex='9am')
morningCol = morningData.columns.values.tolist()

afternoonData = weatherTable.filter(regex='3pm')
afternoonCol = afternoonData.columns.values.tolist()

listToFilter = afternoonCol + morningCol

baseData = weatherTable.drop(listToFilter, axis=1)
baseData
# Out:
#       Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        Cobar     17.9     35.2       0.0         12.0      12.3         SSW
# 1        Cobar     27.1     36.1       0.0         13.0       0.0           N
# 2        Cobar     23.3     34.0       0.0          9.8      12.6         SSW
# 3        Cobar     16.1     34.2       0.0         14.6      13.2          SE
# 4        Cobar     19.0     35.5       0.0         12.0      12.3         ENE
# ...        ...      ...      ...       ...          ...       ...         ...
# 39569   Darwin     21.9     33.0       0.0          5.2      10.9           E
# 39570   Darwin     19.3     33.4       0.0          6.0      11.0         ENE
# 39571   Darwin     21.2     32.6       0.0          7.6       8.6           E
# 39572   Darwin     20.7     32.8       0.0          5.6      11.0           E
# 39573   Darwin     20.2     31.7       0.0          5.6      10.7         ENE
#
# ...

# %%
newMorning = pd.concat([baseData, morningData], axis = 1)
newAfternoon = pd.concat([baseData, afternoonData], axis = 1)

# %%
numRows = 183

morningSmall = newMorning.groupby('Location').head(numRows).reset_index()
afternoonSmall = newAfternoon.groupby('Location').head(numRows).reset_index()

# %%
morningSmall['Location'].value_counts()
# Out:
# Cobar               183
# CoffsHarbour        183
# AliceSprings        183
# Hobart              183
# Perth               183
# PerthAirport        183
# Woomera             183
# Nuriootpa           183
# MountGambier        183
# Townsville          183
# Cairns              183
# Brisbane            183
# Watsonia            183
# Portland            183
# Mildura             183
# Melbourne           183
# MelbourneAirport    183
# Sale                183
# Canberra            183
# Williamtown         183
# WaggaWagga          183
# SydneyAirport       183
# Sydney              183
# NorfolkIsland       183
# Moree               183
# Darwin              183
# Name: Location, dtype: int64

# %%
morningSmall.to_csv("MorningWeatherDataset.csv")
afternoonSmall.to_csv("AfternoonWeatherDataset.csv")
