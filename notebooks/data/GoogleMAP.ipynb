# %%
from google.colab import drive
import os
from os.path import join
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/AI Hack/data/
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/AI Hack/data/'
# /content

# %%
{
  origin: LatLng | String | google.maps.Place, #starting point
  destination: LatLng | String | google.maps.Place, #destination point
  travelMode: TravelMode, #driving(default), bicycling, transit, walking
  transitOptions: TransitOptions, #different transportation ways
  drivingOptions: DrivingOptions, #departure time
  unitSystem: UnitSystem, #showing in km or m
  waypoints[]: DirectionsWaypoint, #do we use it? API document has example script tho
  optimizeWaypoints: Boolean,
  provideRouteAlternatives: Boolean,
  avoidFerries: Boolean,
  avoidHighways: Boolean,
  avoidTolls: Boolean,
  region: String #I dont think we need cos we assume the user only travel in aus
}
#build the related button according to those parameters
#origin, destination, travelMode, provideRouteAlternatives, avoidFerries, avoidHighways, avoidTolls, region
#the departure time is not available in the walking and bicycle mode (only for driving and train)
# Out:
#   File "<ipython-input-3-c1332f70935b>", line 8
#     waypoints[]: DirectionsWaypoint, #do we use it? API document has example script tho
#             ^
# SyntaxError: ':' expected after dictionary key

# %%
import requests
import folium

#the mode choices: driving(default), bicycling, transit, walking
#transit options: arrivaltime, departuretime, modes(bus, rail, subway,train, tram), routingpreference
#

def get_route(api_key, origin, destination, mode="driving"):
    base_url = "https://maps.googleapis.com/maps/api/directions/json"

    #define the parameters
    #https://developers.google.com/maps/documentation/javascript/directions
    params = {
        "origin": origin,
        "destination": destination,
        "mode": mode,
        "key": api_key,
    }

    response = requests.get(base_url, params=params)
    data = response.json()
    #print(data)

    #check data status
    if data["status"] == "OK":
        #extract route
        route = data["routes"][0]["legs"][0]["steps"]

        #create map
        route_map = folium.Map(location=[data["routes"][0]["legs"][0]["start_location"]["lat"], data["routes"][0]["legs"][0]["start_location"]["lng"]], zoom_start=10)

        for step in route:
            #each step: add maker
            start_location = [step["start_location"]["lat"], step["start_location"]["lng"]]
            end_location = [step["end_location"]["lat"], step["end_location"]["lng"]]

            folium.Marker(location=start_location, popup=step["html_instructions"]).add_to(route_map)
            folium.Marker(location=end_location).add_to(route_map)

            #plot the line
            folium.PolyLine([start_location, end_location], color="blue").add_to(route_map)

        #save the html file
        route_map.save("route_map.html")

    else:
        print("Error:", data["status"])

#define Google Maps API key
api_key = "AIzaSyA837gwnpCObaFL58TEMdOyOBP4Y4EPm1w"

#define origin and destination
origin = "Stop 1, Swanston Street, Parkville VIC, Australia"
destination = "Melbourne Central, Melbourne VIC, Australia"

get_route(api_key, origin, destination)

# %%
import requests
import folium

def get_route(api_key, origin, destination, mode="driving"):
    base_url = "https://maps.googleapis.com/maps/api/directions/json"

    params = {
        "origin": origin,
        "destination": destination,
        "mode": mode,
        "key": api_key,
    }

    response = requests.get(base_url, params=params)
    data = response.json()
    print(data)

api_key = "AIzaSyC8gWylw1RpFGE_ZlNbRUE1FIyHMecfb5U"

origin = "New York, NY"
destination = "Los Angeles, CA"

get_route(api_key, origin, destination)
# Out:
# {'error_message': 'API keys with referer restrictions cannot be used with this API.', 'routes': [], 'status': 'REQUEST_DENIED'}

# %%
drive.flush_and_unmount()
