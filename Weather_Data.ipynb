# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuki-lsq/OLPACA/blob/main/Weather_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/My Drive/AI Hack/data/
# %cd /content/drive/MyDrive/AI\ Hack/data/
# Out:
# /content/drive/.shortcut-targets-by-id/1CyICcMXzmLngXU_qcKckXHtD2_qKT_eE/AI Hack/data

# %%
import os
from os.path import join
import numpy as np
import pandas as pd
import random

# %%
home = os.getcwd()
out = join(home, "output")
healthTable = pd.read_csv(join(home, "Health Data.csv"))
healthTable
# Out:
#        Sex  Age  AvgHeight  RSEHeight  AvgWeight  RSEWeight
# 0     Male   18      176.6        0.2       81.1        1.1
# 1     Male   25      176.8        0.2       86.2        0.7
# 2     Male   35      175.7        0.2       88.5        0.8
# 3     Male   45      174.6        0.2       90.4        0.7
# 4     Male   55      173.2        0.2       89.4        0.7
# 5     Male   65      170.7        0.1       85.2        0.6
# 6   Female   18      163.2        0.2       65.9        1.4
# 7   Female   25      162.5        0.1       69.7        0.7
# 8   Female   35      162.4        0.1       73.2        0.8
# 9   Female   45      162.1        0.1       75.1        0.8
# 10  Female   55      160.6        0.1       74.1        0.8
# 11  Female   65      157.4        0.1       71.5        0.6

# %% [markdown]
# Assume we have 100 users, so we will have 100 personal health data. And if we got 10 time points of weather data (e.g. per-30-mins data for 5 hours), we will have 100 × 30 data points of perceived temperature.

# %%
def assumption_data_generator (N, sex):
  ### note: this is the draft framework of generating assumption data, could be amended.
  # N: number of data points
  # sex: the sex of the dataset

  sex = sex.title()
  df = {"sex":[], "age":[], "height":[], "weight":[], "BMI":[], "FreqOfExer":[]}

  for i in range(N):

    df["sex"].append(0) if sex == "Male" else df["sex"].append(1);

    # note: the age should follow the population distribution
    # (didn't find the data with the same age group)
    age = random.randint(18, 100)
    df["age"].append(age)

    rID = healthTable[(healthTable["Age"] <= age) & (healthTable["Sex"] == sex)].index[-1]

    height = round(np.random.normal(healthTable.loc[rID, "AvgHeight"], healthTable.loc[rID, "RSEHeight"]), 2)
    df["height"].append(height)

    weight = round(np.random.normal(healthTable.loc[rID, "AvgWeight"], healthTable.loc[rID, "RSEWeight"]), 2)
    df["weight"].append(weight)

    df["BMI"].append(round(weight/((height/100)**2), 2))

    # df["FreqOfExer"].append(random.randint(0,2))
    if age >= 65:
      df["FreqOfExer"].append(random.randint(0,2))
    else:
      df["FreqOfExer"].append(random.randint(0,7))


  return pd.DataFrame(df)

# %%
data = pd.concat([assumption_data_generator (40, "Male"), assumption_data_generator (35, "Female")])
data.head()
data.to_csv(join(out, "example.csv"))

# %% [markdown]
# TBD: how to generate data with unknown sex? One possible way is to randomly chose one of genders and gernate the data; the other is use the general distribution of height and weight.

# %%
data
# Out:
#     sex  age  height  weight    BMI  FreqOfExer
# 0     0   85  170.67   85.25  29.27           0
# 1     0   98  170.87   85.66  29.34           1
# 2     0   65  170.73   84.86  29.11           2
# 3     0   41  175.82   89.62  28.99           5
# 4     0   74  170.82   85.03  29.14           2
# ..  ...  ...     ...     ...    ...         ...
# 30    1   79  157.41   70.92  28.62           0
# 31    1   86  157.43   71.35  28.79           0
# 32    1   63  160.60   74.92  29.05           7
# 33    1   63  160.72   74.45  28.82           3
# 34    1   22  163.09   67.05  25.21           5
#
# [75 rows x 6 columns]
